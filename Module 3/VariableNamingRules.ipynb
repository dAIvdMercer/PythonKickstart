# %% [markdown]
# <a href="https://colab.research.google.com/github/dAIvdMercer/PythonKickstart/blob/main/Module%203/VariableNamingRules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variable Naming Rules
# **Step 1.** Run the below given code cells sequentially to see if the code runs without any errors.
#
# **Step 2.** Observe the errors generated by the invalid variable names.
#
# **Step 3.** Modify the invalid variable names below to follow Python's naming rules and run the cell again.
#
# **Step 4.** Double-check that all variables are defined correctly and there are no errors.

# %%
my_variable = 10

# %%
# Valid variable name
valid_variable = 20

# %%
# Variable starting with a number
1_variable = 30

# %%
# Variable with spaces
variable with spaces = 40

# %%
# Variable with special characters
variable@with$special_characters = 50

# %%
# Variable using reserved keyword
for = 60
